# %% [markdown]
# <a href="https://colab.research.google.com/github/TonyNguyen001/garbage-classification-cnn/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/gdrive/MyDrive/train_model_garbage_CNN.h5')

# %%
img=load_img("/bin.jpg",target_size=(384, 512))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='battery'
if round(result[0][1])==1:
  prediction='cardboard'
if round(result[0][2])==1:
  prediction='glass'
if round(result[0][3])==1:
  prediction='metal'
if round(result[0][4])==1:
  prediction='paper'
if round(result[0][5])==1:
  prediction='plastic'
print(prediction)
# Out:
# battery

# %%
img=load_img("/content/nhua.jpg",target_size=(384, 512))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='battery'
if round(result[0][1])==1:
  prediction='cardboard'
if round(result[0][2])==1:
  prediction='glass'
if round(result[0][3])==1:
  prediction='metal'
if round(result[0][4])==1:
  prediction='paper'
if round(result[0][5])==1:
  prediction='plastic'
print(prediction)
# Out:
# plastic

# %%
img=load_img("/kimloai.jpg",target_size=(384, 512))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='battery'
if round(result[0][1])==1:
  prediction='cardboard'
if round(result[0][2])==1:
  prediction='glass'
if round(result[0][3])==1:
  prediction='metal'
if round(result[0][4])==1:
  prediction='paper'
if round(result[0][5])==1:
  prediction='plastic'
print(prediction)
# Out:
# metal

# %%
img=load_img("/carton.jpg",target_size=(384, 512))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='battery'
if round(result[0][1])==1:
  prediction='cardboard'
if round(result[0][2])==1:
  prediction='glass'
if round(result[0][3])==1:
  prediction='metal'
if round(result[0][4])==1:
  prediction='paper'
if round(result[0][5])==1:
  prediction='plastic'
print(prediction)
# Out:
# cardboard

# %%
img=load_img("/bao.jpg",target_size=(384, 512))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='battery'
if round(result[0][1])==1:
  prediction='cardboard'
if round(result[0][2])==1:
  prediction='glass'
if round(result[0][3])==1:
  prediction='metal'
if round(result[0][4])==1:
  prediction='paper'
if round(result[0][5])==1:
  prediction='plastic'
print(prediction)
# Out:
# paper

# %%
img=load_img("/thuytinh.jpg",target_size=(384, 512))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='battery'
if round(result[0][1])==1:
  prediction='cardboard'
if round(result[0][2])==1:
  prediction='glass'
if round(result[0][3])==1:
  prediction='metal'
if round(result[0][4])==1:
  prediction='paper'
if round(result[0][5])==1:
  prediction='plastic'
print(prediction)
# Out:
# glass
